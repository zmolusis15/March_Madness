# %% [markdown]
# # March Madness Simulation

# %%
import nbimporter
import importlib
import scoreCalculation
importlib.reload(scoreCalculation)
import pandas as pd
import copy
import numpy as np
from scoreCalculation import simulate_game
from scoreCalculation import calculate_team_rating
from scoreCalculation import load_bracket
from scoreCalculation import madness_sim

# %%
df = pd.read_csv('ratings.csv')

# %%
madness_sim(load_bracket(), df)
# Out:
# 🏀 NCAA March Madness Bracket 🏀
#
#
# 🏀 First Round 🏀
#
# 🌎 East Region:
# 1 Duke ✅
# 16 Marist ❌
# 8 New Mexico ✅
# 9 Connecticut ❌
# 5 Missouri ✅
# 12 Yale ❌
# 4 Purdue ❌
# 13 Lipscomb ✅
# 6 UCLA ❌
# 11 UC San Diego ✅
# 3 Texas Tech ✅
# 14 Towson ❌
# 7 Memphis ❌
# 10 Arkansas ✅
# 2 Tennessee ✅
# 15 Norfolk St. ❌
#
# ------------------------------
# 🌎 West Region:
# 1 Houston ✅
# 16 Nebraska Omaha ❌
# 8 BYU ✅
# 9 Utah St. ❌
# 5 Oregon ✅
# 12 Drake ❌
# 4 St. John's ✅
# 13 Liberty ❌
# 6 Saint Mary's ✅
# 11 Indiana ❌
# 3 Wisconsin ✅
# 14 Chattanooga ❌
# 7 Louisville ❌
# 10 West Virginia ✅
# 2 Florida ✅
# 15 Central Connecticut ❌
#
# ------------------------------
# 🌎 South Region:
# 1 Auburn ✅
# 16 American ❌
# 8 Illinois ❌
# 9 Vanderbilt ✅
# 5 Clemson ❌
# 12 Ohio St. ✅
# 4 Michigan ✅
# 13 High Point ❌
# 6 Marquette ✅
# 11 VCU ❌
# 3 Kentucky ✅
# 14 James Madison ❌
# 7 Mississippi St. ✅
# 10 San Diego St. ❌
# 2 Iowa St. ✅
# 15 Montana ❌
#
# ------------------------------
# ...
